# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielRajChristeen/Pre-trained-Objection-Detection/blob/main/Pre_trained_YOLOv11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pre-Trained Object Detection Model**

# %% [markdown]
# ## **YOLO based object detection**
#
# YOLO (You Only Look Once) is a cutting-edge object detection framework designed to detect and localize multiple objects in a single glance. Unlike older approaches that scan an image in multiple passes, YOLO looks at the entire image just once and predicts all bounding boxes and class probabilities simultaneously. This unified architecture makes it blazing fast and highly efficient, which is why it’s widely used in real-time applications like autonomous driving, video surveillance, and industrial automation.
#
# The model comes in various sizes (like yolo11n.pt, the nano version), which trade off accuracy for speed. The nano variant is exceptionally lightweight, making it ideal for quick prototyping or running on resource-limited hardware.

# %% [markdown]
# ## **Step 1 - install Ultralytics**
# We start by installing the official **ultralytics** package, which provides the full YOLOv8/v9/v11 ecosystem under a single, high-level interface. This gives us pretrained models, training utilities, and deployment tools out of the box.

# %%
# 1. Setup
# !pip install ultralytics

# %% [markdown]
# ## **Step 2 - Setup Dependencies**
# Here we import:
#
# * YOLO from ultralytics — the core model class.
#
# * OpenCV (cv2) — for handling images, video streams, and real-time frames.

# %%
from ultralytics import YOLO
import cv2

# %% [markdown]
# ## **Step 3 - Load Pre-trained YOLOv11 model**
#
# Ultralytics offers multiple model sizes for each YOLO version, each trading accuracy for speed.
# You can plug any of these `.pt` weights into the same `YOLO()` call:
#
# | Model        | Description                                             |
# | ------------ | ------------------------------------------------------- |
# | `yolo11n.pt` | **Nano** — ultra-light, fastest, good for edge devices. |
# | `yolo11s.pt` | **Small** — slightly larger, better accuracy than nano. |
# | `yolo11m.pt` | **Medium** — balanced speed and accuracy.               |
# | `yolo11l.pt` | **Large** — higher accuracy, slower inference.          |
# | `yolo11x.pt` | **Extra-large** — best accuracy, heavy compute load.    |
#
# Here we use `yolo11n.pt`,

# %%
model = YOLO("yolo11n.pt")

# %% [markdown]
# ## **Step 4 — Test with a Single Image**
# We run the image through the model, and get bounding boxes + labels drawn automatically.
# * conf=0.25 - filters out low-confidence predictions to reduce noise.
# * .show() - opens a window with the detections overlaid.

# %%
img_path = "/content/sample.jpg"
results = model(img_path, conf=0.25)
results[0].show()
# Out:
# image 1/1 /content/sample.jpg: 448x640 2 persons, 1 bicycle, 7 cars, 1 truck, 150.2ms
# Speed: 3.7ms preprocess, 150.2ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=872x586>
